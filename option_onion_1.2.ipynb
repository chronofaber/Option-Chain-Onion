# %%
# Import dependencies
#
import requests
from config import username

# %% [markdown]
# ### Request for Put Data

# %%
def get_option_chain_data(ticker, endpoint="https://api.tdameritrade.com/v1/marketdata/chains"):
    
    '''Function to Request Option Chain API raw data for one security.
    The Function has two inputs, a stock ticker and an Endpoint. 
    The Function contains a "payload dictionary" for all the 
    '''
    un_sec = ticker
    #endpoint = endpoint

    #define payload --- GOT TO GET IN THE HABIT OF USING THESE
    payload ={'apikey': username,
              'symbol': un_sec,
              'contractType': 'PUT',
              'strategy': 'ANALYTICAL'}

    #Make a request 
    content = requests.get(url = endpoint, params = payload)

    #request response in json 
    raw_data = content.json()
    return raw_data

# %%
raw_data = get_option_chain_data("GOOG","https://api.tdameritrade.com/v1/marketdata/chains")

# %%
'''
remember json objects are analogus to pythons dictionaries.
as such the type is a dictionary contains the raw object data.
'''
print(type(raw_data))
raw_data
# Out:
# <class 'dict'>
# {'symbol': 'GOOG',
#  'status': 'SUCCESS',
#  'underlying': None,
#  'strategy': 'ANALYTICAL',
#  'interval': 0.0,
#  'isDelayed': True,
#  'isIndex': False,
#  'interestRate': 2.42788,
#  'underlyingPrice': 1365.255,
#  'volatility': 29.0,
#  'daysToExpiration': -1.0,
#  'numberOfContracts': 1690,
#  'callExpDateMap': {},
#  'putExpDateMap': {'2019-12-27:0': {'1000.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1000',
#      'description': 'GOOG Dec 27 2019 1000 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.05,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 3,
#      'bidAskSize': '0X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1577112189519,
#      'quoteTimeInLong': 1577370652195,
#      'netChange': 0.05,
#      'volatility': 133.33,
#      'delta': -0.001,
#      'gamma': 0.0,
#      'theta': -0.079,
#      'vega': 0.002,
#      'rho': 0.0,
#      'openInterest': 47,
#      'timeValue': 0.05,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1000.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 49900.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1005.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1005',
#      'description': 'GOOG Dec 27 2019 1005 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 52,
#      'bidAskSize': '0X52',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999547,
#      'netChange': 0.0,
#      'volatility': 173.53,
#      'delta': -0.007,
#      'gamma': 0.0,
#      'theta': -0.867,
#      'vega': 0.02,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1005.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1010.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1010',
#      'description': 'GOOG Dec 27 2019 1010 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 171.009,
#      'delta': -0.007,
#      'gamma': 0.0,
#      'theta': -0.864,
#      'vega': 0.02,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1010.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1015.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1015',
#      'description': 'GOOG Dec 27 2019 1015 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 168.498,
#      'delta': -0.007,
#      'gamma': 0.0,
#      'theta': -0.862,
#      'vega': 0.02,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1015.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1020.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1020',
#      'description': 'GOOG Dec 27 2019 1020 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 165.996,
#      'delta': -0.007,
#      'gamma': 0.0,
#      'theta': -0.86,
#      'vega': 0.021,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1020.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1025.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1025',
#      'description': 'GOOG Dec 27 2019 1025 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999546,
#      'netChange': 0.0,
#      'volatility': 163.504,
#      'delta': -0.008,
#      'gamma': 0.0,
#      'theta': -0.858,
#      'vega': 0.021,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1025.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1030.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1030',
#      'description': 'GOOG Dec 27 2019 1030 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999547,
#      'netChange': 0.0,
#      'volatility': 161.022,
#      'delta': -0.008,
#      'gamma': 0.0,
#      'theta': -0.856,
#      'vega': 0.021,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1030.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1035.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1035',
#      'description': 'GOOG Dec 27 2019 1035 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 52,
#      'bidAskSize': '0X52',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 158.548,
#      'delta': -0.008,
#      'gamma': 0.0,
#      'theta': -0.853,
#      'vega': 0.022,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1035.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1040.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1040',
#      'description': 'GOOG Dec 27 2019 1040 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.25,
#      'last': 0.0,
#      'mark': 0.13,
#      'bidSize': 0,
#      'askSize': 4,
#      'bidAskSize': '0X4',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393737321,
#      'netChange': 0.0,
#      'volatility': 136.022,
#      'delta': -0.003,
#      'gamma': 0.0,
#      'theta': -0.308,
#      'vega': 0.009,
#      'rho': 0.0,
#      'openInterest': 0,
#      'timeValue': 0.13,
#      'theoreticalOptionValue': 0.125,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1040.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.12,
#      'markPercentChange': 124900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1045.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1045',
#      'description': 'GOOG Dec 27 2019 1045 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 18,
#      'bidAskSize': '0X18',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999941,
#      'netChange': 0.0,
#      'volatility': 153.628,
#      'delta': -0.008,
#      'gamma': 0.0,
#      'theta': -0.848,
#      'vega': 0.022,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1045.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1050.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1050',
#      'description': 'GOOG Dec 27 2019 1050 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 16,
#      'bidAskSize': '0X16',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999940,
#      'netChange': 0.0,
#      'volatility': 151.181,
#      'delta': -0.008,
#      'gamma': 0.0,
#      'theta': -0.846,
#      'vega': 0.022,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1050.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1055.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1055',
#      'description': 'GOOG Dec 27 2019 1055 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 20,
#      'bidAskSize': '0X20',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999959,
#      'netChange': 0.0,
#      'volatility': 148.742,
#      'delta': -0.008,
#      'gamma': 0.0,
#      'theta': -0.844,
#      'vega': 0.023,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1055.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1060.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1060',
#      'description': 'GOOG Dec 27 2019 1060 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.03,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 3,
#      'bidAskSize': '0X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1576599832025,
#      'quoteTimeInLong': 1577370652198,
#      'netChange': 0.03,
#      'volatility': 109.946,
#      'delta': -0.001,
#      'gamma': 0.0,
#      'theta': -0.077,
#      'vega': 0.003,
#      'rho': 0.0,
#      'openInterest': 1,
#      'timeValue': 0.03,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1060.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 29900.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1065.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1065',
#      'description': 'GOOG Dec 27 2019 1065 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.25,
#      'last': 0.0,
#      'mark': 0.13,
#      'bidSize': 0,
#      'askSize': 1,
#      'bidAskSize': '0X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393685036,
#      'netChange': 0.0,
#      'volatility': 125.163,
#      'delta': -0.003,
#      'gamma': 0.0,
#      'theta': -0.304,
#      'vega': 0.01,
#      'rho': 0.0,
#      'openInterest': 0,
#      'timeValue': 0.13,
#      'theoreticalOptionValue': 0.125,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1065.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.12,
#      'markPercentChange': 124900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1070.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1070',
#      'description': 'GOOG Dec 27 2019 1070 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 18,
#      'bidAskSize': '0X18',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999939,
#      'netChange': 0.0,
#      'volatility': 141.476,
#      'delta': -0.009,
#      'gamma': 0.0,
#      'theta': -0.836,
#      'vega': 0.024,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1070.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1075.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1075',
#      'description': 'GOOG Dec 27 2019 1075 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 20,
#      'bidAskSize': '0X20',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999942,
#      'netChange': 0.0,
#      'volatility': 139.07,
#      'delta': -0.009,
#      'gamma': 0.0,
#      'theta': -0.833,
#      'vega': 0.024,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1075.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1080.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1080',
#      'description': 'GOOG Dec 27 2019 1080 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 16,
#      'bidAskSize': '0X16',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999942,
#      'netChange': 0.0,
#      'volatility': 136.672,
#      'delta': -0.009,
#      'gamma': 0.0,
#      'theta': -0.831,
#      'vega': 0.024,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1080.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1085.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1085',
#      'description': 'GOOG Dec 27 2019 1085 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.3,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 3,
#      'bidAskSize': '0X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1575320177201,
#      'quoteTimeInLong': 1577370652198,
#      'netChange': 0.3,
#      'volatility': 100.518,
#      'delta': -0.001,
#      'gamma': 0.0,
#      'theta': -0.076,
#      'vega': 0.003,
#      'rho': 0.0,
#      'openInterest': 2,
#      'timeValue': 0.3,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1085.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 299900.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1090.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1090',
#      'description': 'GOOG Dec 27 2019 1090 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 16,
#      'bidAskSize': '0X16',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999939,
#      'netChange': 0.0,
#      'volatility': 131.898,
#      'delta': -0.009,
#      'gamma': 0.0,
#      'theta': -0.825,
#      'vega': 0.025,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1090.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1095.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1095',
#      'description': 'GOOG Dec 27 2019 1095 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 18,
#      'bidAskSize': '0X18',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999940,
#      'netChange': 0.0,
#      'volatility': 129.521,
#      'delta': -0.009,
#      'gamma': 0.0,
#      'theta': -0.822,
#      'vega': 0.025,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1095.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1100.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1100',
#      'description': 'GOOG Dec 27 2019 1100 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.08,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 3,
#      'bidAskSize': '0X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1577116855175,
#      'quoteTimeInLong': 1577370652198,
#      'netChange': 0.08,
#      'volatility': 94.942,
#      'delta': -0.001,
#      'gamma': 0.0,
#      'theta': -0.075,
#      'vega': 0.003,
#      'rho': 0.0,
#      'openInterest': 10,
#      'timeValue': 0.08,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1100.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 79900.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1105.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1105',
#      'description': 'GOOG Dec 27 2019 1105 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 0.05,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 2,
#      'bidAskSize': '0X2',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1577116803530,
#      'quoteTimeInLong': 1577393991178,
#      'netChange': 0.05,
#      'volatility': 98.889,
#      'delta': -0.002,
#      'gamma': 0.0,
#      'theta': -0.137,
#      'vega': 0.006,
#      'rho': 0.0,
#      'openInterest': 5,
#      'timeValue': 0.05,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1105.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 49900.0,
#      'markChange': 0.05,
#      'markPercentChange': 49900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1110.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1110',
#      'description': 'GOOG Dec 27 2019 1110 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999931,
#      'netChange': 0.0,
#      'volatility': 122.435,
#      'delta': -0.01,
#      'gamma': 0.0,
#      'theta': -0.814,
#      'vega': 0.027,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1110.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1115.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1115',
#      'description': 'GOOG Dec 27 2019 1115 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999933,
#      'netChange': 0.0,
#      'volatility': 120.086,
#      'delta': -0.01,
#      'gamma': 0.0,
#      'theta': -0.811,
#      'vega': 0.027,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1115.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1120.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1120',
#      'description': 'GOOG Dec 27 2019 1120 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 117.744,
#      'delta': -0.01,
#      'gamma': 0.0,
#      'theta': -0.808,
#      'vega': 0.027,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1120.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1125.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1125',
#      'description': 'GOOG Dec 27 2019 1125 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 1.55,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 2,
#      'bidAskSize': '0X2',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1574350506051,
#      'quoteTimeInLong': 1577393991178,
#      'netChange': 1.55,
#      'volatility': 91.171,
#      'delta': -0.002,
#      'gamma': 0.0,
#      'theta': -0.135,
#      'vega': 0.006,
#      'rho': 0.0,
#      'openInterest': 2,
#      'timeValue': 1.55,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1125.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 1549900.09,
#      'markChange': 0.05,
#      'markPercentChange': 49900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1130.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1130',
#      'description': 'GOOG Dec 27 2019 1130 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.75,
#      'last': 0.0,
#      'mark': 0.38,
#      'bidSize': 0,
#      'askSize': 24,
#      'bidAskSize': '0X24',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393998820,
#      'netChange': 0.0,
#      'volatility': 111.24,
#      'delta': -0.01,
#      'gamma': 0.0,
#      'theta': -0.724,
#      'vega': 0.026,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.38,
#      'theoreticalOptionValue': 0.375,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1130.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.37,
#      'markPercentChange': 374900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1135.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1135',
#      'description': 'GOOG Dec 27 2019 1135 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999931,
#      'netChange': 0.0,
#      'volatility': 110.753,
#      'delta': -0.011,
#      'gamma': 0.0,
#      'theta': -0.798,
#      'vega': 0.029,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1135.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1140.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1140',
#      'description': 'GOOG Dec 27 2019 1140 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 108.434,
#      'delta': -0.011,
#      'gamma': 0.0,
#      'theta': -0.795,
#      'vega': 0.029,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1140.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1145.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1145',
#      'description': 'GOOG Dec 27 2019 1145 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 106.121,
#      'delta': -0.011,
#      'gamma': 0.0,
#      'theta': -0.791,
#      'vega': 0.03,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1145.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1150.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1150',
#      'description': 'GOOG Dec 27 2019 1150 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 0.09,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 2,
#      'bidAskSize': '0X2',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1575989037750,
#      'quoteTimeInLong': 1577393991178,
#      'netChange': 0.09,
#      'volatility': 81.653,
#      'delta': -0.002,
#      'gamma': 0.0,
#      'theta': -0.133,
#      'vega': 0.007,
#      'rho': 0.0,
#      'openInterest': 8,
#      'timeValue': 0.09,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1150.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 89900.0,
#      'markChange': 0.05,
#      'markPercentChange': 49900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1152.5': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1152.5',
#      'description': 'GOOG Dec 27 2019 1152.5 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 102.661,
#      'delta': -0.012,
#      'gamma': 0.0,
#      'theta': -0.786,
#      'vega': 0.031,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1152.5,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1155.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1155',
#      'description': 'GOOG Dec 27 2019 1155 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 52,
#      'bidAskSize': '0X52',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 101.51,
#      'delta': -0.012,
#      'gamma': 0.0,
#      'theta': -0.784,
#      'vega': 0.031,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1155.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1157.5': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1157.5',
#      'description': 'GOOG Dec 27 2019 1157.5 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 100.361,
#      'delta': -0.012,
#      'gamma': 0.0,
#      'theta': -0.782,
#      'vega': 0.031,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1157.5,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1160.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1160',
#      'description': 'GOOG Dec 27 2019 1160 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 2.85,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 2,
#      'bidAskSize': '0X2',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1573229359718,
#      'quoteTimeInLong': 1577393991178,
#      'netChange': 2.85,
#      'volatility': 77.883,
#      'delta': -0.002,
#      'gamma': 0.0,
#      'theta': -0.132,
#      'vega': 0.007,
#      'rho': 0.0,
#      'openInterest': 8,
#      'timeValue': 2.85,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1160.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 2849900.08,
#      'markChange': 0.05,
#      'markPercentChange': 49900.0,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1162.5': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1162.5',
#      'description': 'GOOG Dec 27 2019 1162.5 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.0,
#      'volatility': 98.065,
#      'delta': -0.012,
#      'gamma': 0.0,
#      'theta': -0.779,
#      'vega': 0.032,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1162.5,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1165.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1165',
#      'description': 'GOOG Dec 27 2019 1165 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.9,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 52,
#      'bidAskSize': '0X52',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1575901802309,
#      'quoteTimeInLong': 1577393999932,
#      'netChange': 0.9,
#      'volatility': 96.919,
#      'delta': -0.012,
#      'gamma': 0.0,
#      'theta': -0.777,
#      'vega': 0.032,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.9,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1165.0,
#      'expirationDate': 1577498400000,
#      'daysToExpiration': 0,
#      'expirationType': 'S',
#      'lastTradingDay': 1577422800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 899900.04,
#      'markChange': 0.42,
#      'markPercentChange': 424900.01,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': False}],
#    '1167.5': [{'putCall': 'PUT',
#      'symbol': 'GOOG_122719P1167.5',
#      'description': 'GOOG Dec 27 2019 1167.5 Put (Weekly)',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.85,
#      'last': 0.0,
#      'mark': 0.43,
#      'bidSize': 0,
#      'askSize': 51,
#      'bidAskSize': '0X51',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999931,
#      'netChange': 0.0,
#      'volatility': 95.774,
#      'delta': -0.012,
#      'gamma': 0.0,
#      'theta': -0.775,
#      'vega': 0.032,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.43,
#      'theoreticalOptionValue': 0.425,
#      'theoreticalVolatility': 29.0,
# ...
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393989366,
#      'netChange': 0.0,
#      'volatility': 22.432,
#      'delta': -0.78,
#      'gamma': 0.001,
#      'theta': -0.043,
#      'vega': 5.231,
#      'rho': -10.813,
#      'openInterest': 0,
#      'timeValue': 15.65,
#      'theoreticalOptionValue': 415.25,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1760.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -15.46,
#      'markPercentChange': -3.59,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1780.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1780',
#      'description': 'GOOG Jan 21 2022 1780 Put',
#      'exchangeName': 'OPR',
#      'bid': 427.5,
#      'ask': 437.0,
#      'last': 0.0,
#      'mark': 432.25,
#      'bidSize': 1,
#      'askSize': 1,
#      'bidAskSize': '1X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 447.86,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393996193,
#      'netChange': 0.0,
#      'volatility': 22.441,
#      'delta': -0.797,
#      'gamma': 0.001,
#      'theta': -0.04,
#      'vega': 4.937,
#      'rho': -10.377,
#      'openInterest': 0,
#      'timeValue': 12.65,
#      'theoreticalOptionValue': 432.25,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1780.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -15.61,
#      'markPercentChange': -3.49,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1800.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1800',
#      'description': 'GOOG Jan 21 2022 1800 Put',
#      'exchangeName': 'OPR',
#      'bid': 444.5,
#      'ask': 454.0,
#      'last': 0.0,
#      'mark': 449.25,
#      'bidSize': 1,
#      'askSize': 1,
#      'bidAskSize': '1X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 465.22,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393980721,
#      'netChange': 0.0,
#      'volatility': 22.395,
#      'delta': -0.815,
#      'gamma': 0.001,
#      'theta': -0.036,
#      'vega': 4.602,
#      'rho': -9.83,
#      'openInterest': 0,
#      'timeValue': 9.65,
#      'theoreticalOptionValue': 449.25,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1800.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -15.97,
#      'markPercentChange': -3.43,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1820.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1820',
#      'description': 'GOOG Jan 21 2022 1820 Put',
#      'exchangeName': 'OPR',
#      'bid': 462.0,
#      'ask': 471.5,
#      'last': 0.0,
#      'mark': 466.75,
#      'bidSize': 1,
#      'askSize': 1,
#      'bidAskSize': '1X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 482.99,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393995925,
#      'netChange': 0.0,
#      'volatility': 22.4,
#      'delta': -0.831,
#      'gamma': 0.001,
#      'theta': -0.033,
#      'vega': 4.275,
#      'rho': -9.278,
#      'openInterest': 0,
#      'timeValue': 7.15,
#      'theoreticalOptionValue': 466.75,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1820.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -16.24,
#      'markPercentChange': -3.36,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1840.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1840',
#      'description': 'GOOG Jan 21 2022 1840 Put',
#      'exchangeName': 'OPR',
#      'bid': 479.8,
#      'ask': 489.5,
#      'last': 0.0,
#      'mark': 484.65,
#      'bidSize': 1,
#      'askSize': 2,
#      'bidAskSize': '1X2',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 501.27,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999843,
#      'netChange': 0.0,
#      'volatility': 22.444,
#      'delta': -0.847,
#      'gamma': 0.001,
#      'theta': -0.031,
#      'vega': 3.959,
#      'rho': -8.721,
#      'openInterest': 0,
#      'timeValue': 5.05,
#      'theoreticalOptionValue': 484.65,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1840.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -16.62,
#      'markPercentChange': -3.31,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1860.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1860',
#      'description': 'GOOG Jan 21 2022 1860 Put',
#      'exchangeName': 'OPR',
#      'bid': 498.0,
#      'ask': 507.5,
#      'last': 0.0,
#      'mark': 502.75,
#      'bidSize': 1,
#      'askSize': 1,
#      'bidAskSize': '1X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 519.81,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393995845,
#      'netChange': 0.0,
#      'volatility': 22.486,
#      'delta': -0.861,
#      'gamma': 0.001,
#      'theta': -0.028,
#      'vega': 3.631,
#      'rho': -8.114,
#      'openInterest': 0,
#      'timeValue': 3.15,
#      'theoreticalOptionValue': 502.75,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1860.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -17.06,
#      'markPercentChange': -3.28,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1880.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1880',
#      'description': 'GOOG Jan 21 2022 1880 Put',
#      'exchangeName': 'OPR',
#      'bid': 516.5,
#      'ask': 526.0,
#      'last': 0.0,
#      'mark': 521.25,
#      'bidSize': 1,
#      'askSize': 1,
#      'bidAskSize': '1X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 538.53,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999598,
#      'netChange': 0.0,
#      'volatility': 22.588,
#      'delta': -0.874,
#      'gamma': 0.001,
#      'theta': -0.025,
#      'vega': 3.334,
#      'rho': -7.55,
#      'openInterest': 0,
#      'timeValue': 1.65,
#      'theoreticalOptionValue': 521.25,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1880.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -17.28,
#      'markPercentChange': -3.21,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1900.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1900',
#      'description': 'GOOG Jan 21 2022 1900 Put',
#      'exchangeName': 'OPR',
#      'bid': 535.5,
#      'ask': 545.5,
#      'last': 0.0,
#      'mark': 540.5,
#      'bidSize': 1,
#      'askSize': 3,
#      'bidAskSize': '1X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 557.52,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393995774,
#      'netChange': 0.0,
#      'volatility': 22.882,
#      'delta': -0.881,
#      'gamma': 0.001,
#      'theta': -0.024,
#      'vega': 3.162,
#      'rho': -7.254,
#      'openInterest': 0,
#      'timeValue': 0.9,
#      'theoreticalOptionValue': 540.5,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1900.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -17.02,
#      'markPercentChange': -3.05,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1920.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1920',
#      'description': 'GOOG Jan 21 2022 1920 Put',
#      'exchangeName': 'OPR',
#      'bid': 555.0,
#      'ask': 565.0,
#      'last': 0.0,
#      'mark': 560.0,
#      'bidSize': 3,
#      'askSize': 1,
#      'bidAskSize': '3X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 576.81,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393999956,
#      'netChange': 0.0,
#      'volatility': 23.24,
#      'delta': -0.886,
#      'gamma': 0.001,
#      'theta': -0.024,
#      'vega': 3.039,
#      'rho': -7.057,
#      'openInterest': 0,
#      'timeValue': 0.4,
#      'theoreticalOptionValue': 560.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1920.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -16.81,
#      'markPercentChange': -2.91,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1940.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1940',
#      'description': 'GOOG Jan 21 2022 1940 Put',
#      'exchangeName': 'OPR',
#      'bid': 575.0,
#      'ask': 585.0,
#      'last': 0.0,
#      'mark': 580.0,
#      'bidSize': 3,
#      'askSize': 3,
#      'bidAskSize': '3X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 596.44,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393980591,
#      'netChange': 0.0,
#      'volatility': 23.756,
#      'delta': -0.886,
#      'gamma': 0.001,
#      'theta': -0.025,
#      'vega': 3.026,
#      'rho': -7.113,
#      'openInterest': 0,
#      'timeValue': 0.4,
#      'theoreticalOptionValue': 580.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1940.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -16.44,
#      'markPercentChange': -2.76,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1960.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1960',
#      'description': 'GOOG Jan 21 2022 1960 Put',
#      'exchangeName': 'OPR',
#      'bid': 595.0,
#      'ask': 605.0,
#      'last': 652.0,
#      'mark': 600.0,
#      'bidSize': 3,
#      'askSize': 3,
#      'bidAskSize': '3X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 616.44,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1575041352294,
#      'quoteTimeInLong': 1577393980615,
#      'netChange': 35.56,
#      'volatility': 24.269,
#      'delta': -0.885,
#      'gamma': 0.001,
#      'theta': -0.025,
#      'vega': 3.016,
#      'rho': -7.171,
#      'openInterest': 3,
#      'timeValue': 52.4,
#      'theoreticalOptionValue': 600.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1960.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 5.77,
#      'markChange': -16.44,
#      'markPercentChange': -2.67,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '1980.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P1980',
#      'description': 'GOOG Jan 21 2022 1980 Put',
#      'exchangeName': 'OPR',
#      'bid': 615.0,
#      'ask': 625.0,
#      'last': 657.0,
#      'mark': 620.0,
#      'bidSize': 3,
#      'askSize': 3,
#      'bidAskSize': '3X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 636.44,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1575572074575,
#      'quoteTimeInLong': 1577393980591,
#      'netChange': 20.56,
#      'volatility': 24.779,
#      'delta': -0.885,
#      'gamma': 0.001,
#      'theta': -0.026,
#      'vega': 3.01,
#      'rho': -7.231,
#      'openInterest': 1,
#      'timeValue': 37.4,
#      'theoreticalOptionValue': 620.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 1980.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 3.23,
#      'markChange': -16.44,
#      'markPercentChange': -2.58,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}],
#    '2000.0': [{'putCall': 'PUT',
#      'symbol': 'GOOG_012122P2000',
#      'description': 'GOOG Jan 21 2022 2000 Put',
#      'exchangeName': 'OPR',
#      'bid': 635.0,
#      'ask': 645.0,
#      'last': 0.0,
#      'mark': 640.0,
#      'bidSize': 3,
#      'askSize': 3,
#      'bidAskSize': '3X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 656.44,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1577393980595,
#      'netChange': 0.0,
#      'volatility': 25.287,
#      'delta': -0.884,
#      'gamma': 0.001,
#      'theta': -0.027,
#      'vega': 3.007,
#      'rho': -7.295,
#      'openInterest': 0,
#      'timeValue': 0.4,
#      'theoreticalOptionValue': 640.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2000.0,
#      'expirationDate': 1642816800000,
#      'daysToExpiration': 756,
#      'expirationType': 'R',
#      'lastTradingDay': 1642741200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -16.44,
#      'markPercentChange': -2.5,
#      'nonStandard': False,
#      'mini': False,
#      'inTheMoney': True}]}}}

# %% [markdown]
# We end up with the First Layer of The Onion, which is is a dictionary comprising of 14 key value pairs.

# %% [markdown]
# ### Unfolding the Blooming Data Onion
# Accessing Nested Dictionary Keys

# %% [markdown]
# #### Step 1 - Get Security Name
#
# We Create a Function to extract the security Name, we simply call the key value pair in *raw_data* which can be called through the key value *symbol*. We will create this function **get_who()** in the next cell.

# %%
def get_who(raw_data): #added 
    '''
    Function that returns the stock ticker
    '''
    Who = raw_data['symbol']
    return Who

# %% [markdown]
# This gives us the security ticker in the form of a string.

# %% [markdown]
# #### Step 2 - Unfold The Onion
#
# What follows is a deep dive into the different layers of the json data, which we called *raw_data*.
#
# I liken the following problem like an Onion because the python dictionary object is comprised of key/value tuples.
#
# The values are not constrained to simple one-to-one relation like say if we had an data *type* like *strings* or *integers*, but can also be a *list* object or even another *dictionary* object.
#
# To illustrate lets look at the results from **get_who()**, which return a single str object.

# %%
inception_0 = raw_data['putExpDateMap'] 
'''
dictionary containing collection of items ___??
'''
print(type(inception_0))
print("There are", len(inception_0), "key:value pairs in the dictionary")
inception_0['2019-12-27:5']

# %% [markdown]
# ### Step 3 - Layer Inception

# %%
def get_keylist(inception_0): # dictionary method....
    print("There are", len(inception_0), "key:value pairs in the dictionary")
    #for i in inception_0:
        #print(i)
        #print(i, inception_0[i])
    #    return i
    d = [*inception_0]
    return d

# %%
#print(type(get_keylist(inception_0)))
keys_0 = get_keylist(inception_0)
keys_0

# %%
inception_1 = inception_0['2019-12-27:5'] # this dictionary is a collection of lists.
print(type(inception_1))
inception_1 
print(len(inception_1))

# %%
strike_keys = get_keylist(inception_1)
strike_keys

# %%
inception_2 = inception_1[strike_keys[0]] 
print(type(inception_2))
print(len(inception_2))
inception_2

# %%
inception_3 = inception_2[0] # this is a one item list 
inception_3

# %% [markdown]
# #### Step 4 - Create Helper Function

# %% [markdown]
# We create a helper function that uses inline methods to create a list from a range. By utilizing  * *x* and the *range* method we can do it in three lines of code.

# %%
# Onion Helper Function 1 creates a range with n steps
def helper_range_to_list(start,end,step):
    x = range(start,end+1, step)
    list_of_strike_prices = [*x]
    return(list_of_strike_prices)
    '''
    x is a range from 1000 to 2000 in 5 step increments.
    we get list_of_strike_prices  by using * in a list literal []: 
    introduced in python 3.5,
    alternative use list_of_strike_prices = list(x) or something of the sort
    '''

# %%
print(type(helper_range_to_list(1000,2000,5)))
helper_range_to_list(1000,2000,5)

# %%
#'''
#This is the dictionary that was in the 'PutExpDateMap', which is
#a nested dictionary containing all the info for a Google Put Chain from $1000.00
#
#'''

# %%
symception_2 ## single record of a strike price.

# %%
print(type(symception_0))

# %%
print(type(symception_1))

# %%
print(type(symception_2))

# %%
print(type(symception_3))

# %%
symception_3 = symception_2[0]

# %%
symception_3

# %%
type(symception_3)

# %%
symception_3['bid']
symception_
